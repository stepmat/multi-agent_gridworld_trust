# %%
"""
Multi-Agent Dynamic Grid World Environment
Created by: Ardianto Wibowo
"""

import numpy as np
import sys

# Add the path to the 'env' folder to sys.path
sys.path.append('env')

from ma_gridworld import Env

class QLearningAgent:
    def __init__(self, num_actions, alpha=0.1, gamma=0.9, epsilon=0.1):
        self.num_actions = num_actions
        self.q_table = {}  # Dictionary to store Q-values for each (x, y) coordinate
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    def select_action(self, state):
        """Select an action using epsilon-greedy policy."""
        # Initialize Q-values if state is not in the q_table
        if state not in self.q_table:
            self.q_table[state] = [0] * self.num_actions
        
        if np.random.rand() < self.epsilon:
            return np.random.choice(self.num_actions)  # Explore
        else:
            return np.argmax(self.q_table[state])  # Exploit

    def update_q_table(self, state, action, reward, next_state):
        """Update the Q-value for the given state-action pair."""
        # Initialize Q-values if state or next_state is not in the q_table
        if state not in self.q_table:
            self.q_table[state] = [0] * self.num_actions
        if next_state not in self.q_table:
            self.q_table[next_state] = [0] * self.num_actions
        
        best_next_action = np.argmax(self.q_table[next_state])
        self.q_table[state][action] += self.alpha * (
            reward + self.gamma * self.q_table[next_state][best_next_action] - self.q_table[state][action]
        )

    def decay_epsilon(self, epsilon_decay, epsilon_min):
        """Decay epsilon after each episode."""
        self.epsilon = max(self.epsilon * epsilon_decay, epsilon_min)


def get_action(agent_id, observation, num_actions, agents, env):
    """
    This method provides an action chosen by each agent's Q-table:
    1: up, 2: down, 3: left, 4: right, 0: stay
    """
    coordinate_observation = tuple(observation[0])  # Keep observation as (x, y) tuple

    #optional observation data may be used, depend on the agent needs.
    win_state_observation = observation[1]
    sensor_data_observation = observation[2]
    comm_observation = observation[3]

    physical_action = agents[agent_id].select_action(coordinate_observation)

    if env.is_agent_silent:
        comm_action = []  # No communication if agent is silent
    else:
        comm_action = np.random.choice(num_actions)  # Example random communication action

    return physical_action, comm_action


def run(num_episodes, max_steps_per_episode, agents, num_actions, env, epsilon_decay=0.95, epsilon_min=0.01):
    for episode in range(num_episodes):
        print(f"Starting episode {episode + 1}")
        
        observations = env.reset()  # Reset the environment at the start of each episode
        done = [False] * env.num_agents
        step_count = 0

        while not all(done) and step_count < max_steps_per_episode:
            actions = []
            next_observations = []

            for agent_id in range(env.num_agents):
                observation = observations[agent_id]
                action = get_action(agent_id, observation, num_actions, agents, env)
                
                actions.append(action)
                next_observations.append(observation)

            next_observations, rewards, done = env.step(actions)
            step_count += 1

            # Update Q-tables for each agent
            for agent_id in range(env.num_agents):
                observation = observations[agent_id]
                coordinate_observation = tuple(observation[0])  # Use (x,y) tuple as observation data

                reward = rewards[agent_id]

                action = actions[agent_id]
                physical_action = action[0]
                
                next_observation = next_observations[agent_id]
                coordinate_next_observation = tuple(next_observation[0])  # Use (x,y) tuple as next observation data
                
                #optional next observation data may be used, depend on the agent needs.
                win_state_next_observation = next_observation[1]
                sensor_data_next_observation = next_observation[2]
                comm_next_observation = next_observation[3]


                agents[agent_id].update_q_table(coordinate_observation, physical_action, reward, coordinate_next_observation)

            observations = next_observations
            
            # Render the environment
            env.render()

            print(f"Step {step_count}:")
            for agent_id in range(env.num_agents):
                print(f"  Agent {agent_id}: Observation: {observations}, Action: {actions[agent_id]}, Reward: {rewards[agent_id]}, Done: {done[agent_id]}")

        print(f"Episode {episode + 1} finished after {step_count} steps.\n")

        # Decay epsilon for each agent
        for agent in agents:
            agent.decay_epsilon(epsilon_decay, epsilon_min)



if __name__ == "__main__":

    gsize=15 #grid size (square)
    gpixels=30 #grid cell size in pixels

    is_sensor_active = True #True:  Activate the sensory observation data
    sensory_size = 3 #'is_sensor_active' must be True. The value must be odd, if event will be converted to one level odd number above
    
    num_agents = 3 #the number of agents will be run in paralel
    num_obstacles = 10 #the number of obstacles
    is_single_target = False #True: all agents have a single target, False: each agent has their own target
    num_targets_per_agent = 2 #'is_single_target' must be False to have an effect
    
    is_agent_silent = True #True: communication among agents is allowed

    num_episodes=150 #the number of episode will be run
    max_steps_per_episode=400 #each episode will be stopped when max_step is reached

    eps_moving_targets = 151 #set this value greater than 'num_episodes' to keep the targets in a stationary position
    eps_moving_obstacles = 151 #set this value greater than 'num_episodes' to keep the obstacles in a stationary position

    render = True #True: render the animation into the screen (so far, it is still can not be deactivated)

    min_obstacle_distance_from_target = 1 #min grid distance of each obstacles relative to targets
    max_obstacle_distance_from_target = 5 #max grid distance of each obstacles relative to targets
    min_obstacle_distance_from_agents = 1 #min grid distance of each obstacles relative to agents

    reward_normal = -1 #reward value of normal steps
    reward_obstacle = -5 #reward value when hit an obstacle
    reward_target = 50 #reward value when reach the target

    is_totally_random = False #True: target and obstacles initial as well as movement position is always random on each call, False: only random at the beginning. 
    animation_speed = 0.0000001 #smaller is faster 
    is_destroy_environment = True #True: automatically close the animation after all episodes end.  

    # Initialize environment
    env = Env(
        num_agents=num_agents, num_targets_per_agent=num_targets_per_agent, num_obstacles=num_obstacles,
        eps_moving_obstacles=eps_moving_obstacles, eps_moving_targets=eps_moving_targets,
        is_agent_silent=is_agent_silent, is_single_target=is_single_target, sensory_size=sensory_size,
        gpixels=gpixels, gheight=gsize, gwidth=gsize, is_sensor_active=is_sensor_active,
        min_obstacle_distance_from_target=min_obstacle_distance_from_target,
        max_obstacle_distance_from_target=max_obstacle_distance_from_target,
        min_obstacle_distance_from_agents=min_obstacle_distance_from_agents,
        is_totally_random=is_totally_random, animation_speed=animation_speed,
        reward_normal=reward_normal, reward_obstacle=reward_obstacle, reward_target=reward_target
    )

    alpha=0.1
    gamma=0.9
    epsilon=0.1
    epsilon_decay = 0.95 
    epsilon_min = 0.01
    num_actions = len(env.action_space)

    # Initialize Q-learning agents
    agents = [QLearningAgent(num_actions, alpha, gamma, epsilon) for _ in range(num_agents)]

    # Run episodes
    run(num_episodes, max_steps_per_episode, agents, num_actions, env, epsilon_decay, epsilon_min)

    # Destroy environment if needed
    if is_destroy_environment:
        env.destroy_environment()
# Out:
# Starting episode 1
# Step 1:
#   Agent 0: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 14], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'agent'], [None, None, None]], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 14], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'agent'], [None, None, None]], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 14], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'agent'], [None, None, None]], []]], Action: (3, []), Reward: -1, Done: False
# Step 2:
#   Agent 0: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 14], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], [None, None, None]], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 14], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], [None, None, None]], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 14], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], [None, None, None]], []]], Action: (0, []), Reward: -1, Done: False
# Step 3:
#   Agent 0: Observation: [[[0, 1], False, [[None, 'agent', 'empty'], [None, 'empty', 'empty'], [None, 'empty', 'target_2_0']], []], [[14, 1], False, [['empty', 'agent', None], ['empty', 'empty', None], ['empty', 'empty', None]], []], [[13, 13], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 1], False, [[None, 'agent', 'empty'], [None, 'empty', 'empty'], [None, 'empty', 'target_2_0']], []], [[14, 1], False, [['empty', 'agent', None], ['empty', 'empty', None], ['empty', 'empty', None]], []], [[13, 13], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 1], False, [[None, 'agent', 'empty'], [None, 'empty', 'empty'], [None, 'empty', 'target_2_0']], []], [[14, 1], False, [['empty', 'agent', None], ['empty', 'empty', None], ['empty', 'empty', None]], []], [[13, 13], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Step 4:
#   Agent 0: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'agent', 'empty'], [None, 'empty', 'target_2_0']], []], [[14, 2], False, [['empty', 'agent', None], ['empty', 'empty', None], ['empty', 'empty', None]], []], [[13, 13], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'agent', 'empty'], [None, 'empty', 'target_2_0']], []], [[14, 2], False, [['empty', 'agent', None], ['empty', 'empty', None], ['empty', 'empty', None]], []], [[13, 13], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'agent', 'empty'], [None, 'empty', 'target_2_0']], []], [[14, 2], False, [['empty', 'agent', None], ['empty', 'empty', None], ['empty', 'empty', None]], []], [[13, 13], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Step 5:
#   Agent 0: Observation: [[[0, 0], False, [[None, None, None], [None, 'empty', 'empty'], [None, 'agent', 'empty']], []], [[14, 2], False, [['empty', 'empty', None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 12], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 0], False, [[None, None, None], [None, 'empty', 'empty'], [None, 'agent', 'empty']], []], [[14, 2], False, [['empty', 'empty', None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 12], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 0], False, [[None, None, None], [None, 'empty', 'empty'], [None, 'agent', 'empty']], []], [[14, 2], False, [['empty', 'empty', None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 12], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Step 6:
#   Agent 0: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 1], False, [['empty', 'empty', None], ['empty', 'empty', None], ['empty', 'agent', None]], []], [[13, 12], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 1], False, [['empty', 'empty', None], ['empty', 'empty', None], ['empty', 'agent', None]], []], [[13, 12], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[14, 1], False, [['empty', 'empty', None], ['empty', 'empty', None], ['empty', 'agent', None]], []], [[13, 12], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Step 7:
#   Agent 0: Observation: [[[1, 0], False, [[None, None, None], ['agent', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[14, 1], False, [['empty', 'empty', None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 11], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (4, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[1, 0], False, [[None, None, None], ['agent', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[14, 1], False, [['empty', 'empty', None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 11], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 0], False, [[None, None, None], ['agent', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[14, 1], False, [['empty', 'empty', None], ['empty', 'agent', None], ['empty', 'empty', None]], []], [[13, 11], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Step 8:
#   Agent 0: Observation: [[[0, 0], False, [[None, None, None], [None, 'empty', 'agent'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'empty', None], ['empty', 'agent', None]], []], [[13, 11], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 0], False, [[None, None, None], [None, 'empty', 'agent'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'empty', None], ['empty', 'agent', None]], []], [[13, 11], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 0], False, [[None, None, None], [None, 'empty', 'agent'], [None, 'empty', 'empty']], []], [[14, 0], False, [[None, None, None], ['empty', 'empty', None], ['empty', 'agent', None]], []], [[13, 11], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Step 9:
#   Agent 0: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 10], False, [['empty', 'target_0_1', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 10], False, [['empty', 'target_0_1', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 10], False, [['empty', 'target_0_1', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Step 10:
#   Agent 0: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 10], False, [['empty', 'target_0_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 10], False, [['empty', 'target_0_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 0], False, [[None, None, None], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 10], False, [['empty', 'target_0_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Agent 2 hit another agent's target! Next state: [13, 9]
# Step 11:
#   Agent 0: Observation: [[[0, 1], False, [[None, 'agent', 'empty'], [None, 'empty', 'empty'], [None, 'empty', 'target_2_0']], []], [[13, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'target_0_1', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 1], False, [[None, 'agent', 'empty'], [None, 'empty', 'empty'], [None, 'empty', 'target_2_0']], []], [[13, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'target_0_1', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 1], False, [[None, 'agent', 'empty'], [None, 'empty', 'empty'], [None, 'empty', 'target_2_0']], []], [[13, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'target_0_1', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -5, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 12:
#   Agent 0: Observation: [[[0, 2], False, [[None, 'agent', 'empty'], [None, 'empty', 'target_2_0'], [None, 'empty', 'empty']], []], [[13, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 2], False, [[None, 'agent', 'empty'], [None, 'empty', 'target_2_0'], [None, 'empty', 'empty']], []], [[13, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 2], False, [[None, 'agent', 'empty'], [None, 'empty', 'target_2_0'], [None, 'empty', 'empty']], []], [[13, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 13:
#   Agent 0: Observation: [[[0, 3], False, [[None, 'agent', 'target_2_0'], [None, 'empty', 'empty'], [None, 'empty', 'empty']], []], [[13, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 3], False, [[None, 'agent', 'target_2_0'], [None, 'empty', 'empty'], [None, 'empty', 'empty']], []], [[13, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 3], False, [[None, 'agent', 'target_2_0'], [None, 'empty', 'empty'], [None, 'empty', 'empty']], []], [[13, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 14:
#   Agent 0: Observation: [[[0, 3], False, [[None, 'empty', 'target_2_0'], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 3], False, [[None, 'empty', 'target_2_0'], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 3], False, [[None, 'empty', 'target_2_0'], [None, 'agent', 'empty'], [None, 'empty', 'empty']], []], [[13, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 15:
#   Agent 0: Observation: [[[0, 2], False, [[None, 'empty', 'empty'], [None, 'empty', 'target_2_0'], [None, 'agent', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 2], False, [[None, 'empty', 'empty'], [None, 'empty', 'target_2_0'], [None, 'agent', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 2], False, [[None, 'empty', 'empty'], [None, 'empty', 'target_2_0'], [None, 'agent', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 16:
#   Agent 0: Observation: [[[0, 2], False, [[None, 'empty', 'empty'], [None, 'agent', 'target_2_0'], [None, 'empty', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 2], False, [[None, 'empty', 'empty'], [None, 'agent', 'target_2_0'], [None, 'empty', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 2], False, [[None, 'empty', 'empty'], [None, 'agent', 'target_2_0'], [None, 'empty', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 17:
#   Agent 0: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'empty', 'empty'], [None, 'agent', 'target_2_0']], []], [[12, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'empty', 'empty'], [None, 'agent', 'target_2_0']], []], [[12, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'empty', 'empty'], [None, 'agent', 'target_2_0']], []], [[12, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 18:
#   Agent 0: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'agent', 'empty'], [None, 'empty', 'target_2_0']], []], [[12, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'agent', 'empty'], [None, 'empty', 'target_2_0']], []], [[12, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[0, 1], False, [[None, 'empty', 'empty'], [None, 'agent', 'empty'], [None, 'empty', 'target_2_0']], []], [[12, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 19:
#   Agent 0: Observation: [[[1, 1], False, [['empty', 'empty', 'empty'], ['agent', 'empty', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[12, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (4, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[1, 1], False, [['empty', 'empty', 'empty'], ['agent', 'empty', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[12, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 1], False, [['empty', 'empty', 'empty'], ['agent', 'empty', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[12, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 20:
#   Agent 0: Observation: [[[1, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[1, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[12, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 21:
#   Agent 0: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 22:
#   Agent 0: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 23:
#   Agent 0: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 2 is locked. Done status: True, win status: False
# Step 24:
#   Agent 0: Observation: [[[1, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 1: Observation: [[[1, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'target_2_0', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 hit another agent's target! Next state: [1, 2]
# Agent 2 is locked. Done status: True, win status: False
# Step 25:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'agent', 'empty'], ['empty', 'target_2_0', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -5, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'agent', 'empty'], ['empty', 'target_2_0', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'agent', 'empty'], ['empty', 'target_2_0', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 26:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 27:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[11, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 28:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'empty', 'agent'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 29:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 30:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 31:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['obstacle', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['obstacle', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (2, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['obstacle', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 32:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['obstacle', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['obstacle', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['obstacle', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 33:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 1], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'agent'], ['empty', 'obstacle', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 1], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'agent'], ['empty', 'obstacle', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (3, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 1], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'agent'], ['empty', 'obstacle', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 34:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'obstacle', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'obstacle', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 1], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'obstacle', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 35:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 36:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 37:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 38:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
#   Agent 2: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 0], False, [[None, None, None], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# Agent 0 is locked. Done status: True, win status: False
# Agent 2 is locked. Done status: True, win status: False
# Step 39:
#   Agent 0: Observation: [[[1, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[9, 1], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'obstacle', 'empty']], []], [[13, 9], False, [['empty', 'target_2_1', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
# ...
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 42:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 10], False, [['obstacle', 'empty', 'obstacle'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 10], False, [['obstacle', 'empty', 'obstacle'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 10], False, [['obstacle', 'empty', 'obstacle'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 43:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 10], False, [['obstacle', 'empty', 'obstacle'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 10], False, [['obstacle', 'empty', 'obstacle'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 10], False, [['obstacle', 'empty', 'obstacle'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 44:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 9], False, [['empty', 'empty', 'empty'], ['obstacle', 'empty', 'obstacle'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 9], False, [['empty', 'empty', 'empty'], ['obstacle', 'empty', 'obstacle'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 9], False, [['empty', 'empty', 'empty'], ['obstacle', 'empty', 'obstacle'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 45:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 9], False, [['empty', 'empty', 'empty'], ['obstacle', 'agent', 'obstacle'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 9], False, [['empty', 'empty', 'empty'], ['obstacle', 'agent', 'obstacle'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 9], False, [['empty', 'empty', 'empty'], ['obstacle', 'agent', 'obstacle'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 46:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 8], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['obstacle', 'agent', 'obstacle']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 8], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['obstacle', 'agent', 'obstacle']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 8], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['obstacle', 'agent', 'obstacle']], []]], Action: (1, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 47:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 8], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['obstacle', 'empty', 'obstacle']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 8], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['obstacle', 'empty', 'obstacle']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 8], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['obstacle', 'empty', 'obstacle']], []]], Action: (0, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 48:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 7], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 7], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 7], False, [['empty', 'empty', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 49:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 7], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 7], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 7], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 50:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 6], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 6], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 6], False, [['empty', 'agent', 'empty'], ['empty', 'empty', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Step 51:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []], [[10, 6], False, [['empty', 'agent', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []], [[10, 6], False, [['empty', 'agent', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []], [[10, 6], False, [['empty', 'agent', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []]], Action: (0, []), Reward: -1, Done: False
# Agent 0 is locked. Done status: True, win status: False
# Agent 1 is locked. Done status: True, win status: False
# Agent 2 hit an obstacle! Next state: [10, 5]
# Step 52:
#   Agent 0: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 1: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (0, []), Reward: 0, Done: True
#   Agent 2: Observation: [[[3, 2], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'empty', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []], [[10, 5], False, [['empty', 'empty', 'empty'], ['empty', 'agent', 'empty'], ['empty', 'agent', 'empty']], []]], Action: (1, []), Reward: -5, Done: True
# Episode 7 finished after 52 steps.
#
# Starting episode 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 192
#     189 agents = [QLearningAgent(num_actions, alpha, gamma, epsilon) for _ in range(num_agents)]
#     191 # Run episodes
# --> 192 run(num_episodes, max_steps_per_episode, agents, num_actions, env, epsilon_decay, epsilon_min)
#     194 # Destroy environment if needed
#     195 if is_destroy_environment:
#
# Cell In[1], line 77, in run(num_episodes, max_steps_per_episode, agents, num_actions, env, epsilon_decay, epsilon_min)
#      74 for episode in range(num_episodes):
#      75     print(f"Starting episode {episode + 1}")
# ---> 77     observations = env.reset()  # Reset the environment at the start of each episode
#      78     done = [False] * env.num_agents
#      79     step_count = 0
#
# File ~/PHD/Research/code/ma-gridworld/env/ma_gridworld.py:239, in Env.reset(self)
#     237 def reset(self):
#     238     self.update()
# --> 239     time.sleep(0.5)
#     240     for agent, initial_pos in zip(self.agents, self.initial_agent_positions):
#     241         x, y = initial_pos
#
# KeyboardInterrupt:
